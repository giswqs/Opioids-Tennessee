# %% [markdown]
# ## Reshaping Clinics Data

# %%
import os
import numpy as np
import pandas as pd

# %%
# get current working directory
cwd = os.getcwd()

# set input and output Excel files
in_excel_file = os.path.join(cwd, 'data', 'pain_clinics_historic_to_20190820.xlsx')
out_excel_file = os.path.join(cwd, 'data', 'KnoxvilleAreapain_clinics.xlsx')

# read Excel file 
df = pd.read_excel(in_excel_file,header=None)

# show the first ten rows
df.head(10)
# Out:
#      0                               1                                      2  \
# 0  1.0           Absolute Medical Care         Medical Director: Hau La, M.D.
# 1  NaN          713 B President Place                                     NaN
# 2  NaN                Smyrna, TN 37167                                    NaN
# 3  NaN                    615-667-1299                                    NaN
# 4  NaN                             NaN                                    NaN
# 5  2.0  ACCELERATED MEDICAL OF SEYMOUR  Medical Director: GHOLAMREZA SHAREGHI
# 6  NaN           319 BLUE PEACOCK WAY                                     NaN
# 7  NaN               Seymour, TN 37865                                    NaN
# 8  NaN                    865-216-8930                                    NaN
# 9  NaN                             NaN                                    NaN
#
#                                         3
# 0       Facility License Number: 00000592
# 1                 Status: Lic Surrendered
# 2  Date of Original Licensure: 03/07/2016
# 3          Date of Expiration: 03/31/2018
# 4                1 Disciplinary Action(s)
# 5       Facility License Number: 00000000
# 6                     Status: Closed Appl
# 7            Date of Original Licensure:
# 8                    Date of Expiration:
# 9                 No Disciplinary Actions

# %%
# define a list for storing info about each clinic
clinics = []

# loop through each row
for row_index in range(0, len(df.index)):
    row = df.iloc[row_index]
    if row[0] > 0:
        
        clinic = {}
        clinic['Id'] = row[0]
       
        # fix records with missing information, such as city name, phone, etc.
        if clinic['Id'] == 55:
            df.set_value(row_index + 2, 1, 'Johnson City, TN 37601')
        if clinic['Id'] == 542:
            df.set_value(row_index + 2, 1, 'Columbia, TN 38401')  
        if clinic['Id'] == 98:
            df.set_value(row_index, 2, 'Medical Director: NA')
        if clinic['Id'] in [122, 145, 398, 496, 542, 545, 548, 553, 639, 752]:
            df.set_value(row_index + 3, 1, '000-000-0000')         

        # extract clinic info
        clinic['Name'] = row[1]
        clinic['MedDirector'] = str(row[2]).split(":")[1].strip()
        clinic['FacLicNum'] = row[3].split(":")[1].strip()
        clinic['Street'] = df.iloc[row_index + 1][1].strip()
        clinic['Status'] = df.iloc[row_index + 1][3].split(":")[1].strip()
        clinic['City'] = df.iloc[row_index + 2][1].split(',')[0].strip()
        clinic['State'] = df.iloc[row_index + 2][1].split(',')[1].strip().split(' ')[0]
        clinic['Zip'] = df.iloc[row_index + 2][1].split(',')[1].strip().split(' ')[1]
        clinic['OrgLic'] = df.iloc[row_index + 2][3].split(":")[1].strip()
        clinic['Phone'] = df.iloc[row_index + 3][1].strip()
        clinic['ExpDate'] = df.iloc[row_index + 3][3].split(":")[1].strip()
        clinic['Displinary'] = df.iloc[row_index + 4][3].strip()
        clinics.append(clinic)        
        
    else:
        pass
# Out:
# /home/qiusheng/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# /home/qiusheng/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/qiusheng/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# /home/qiusheng/.conda/envs/py37/lib/python3.7/site-packages/ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()

# %%
print(f"Total number of clinics: {len(clinics)}")
# Out:
# Total number of clinics: 849

# %%
# convert list to datafroame
out_df = pd.DataFrame(clinics)

# %%
# show the first five rows. Note that columns are order alphabetically
out_df.head()
# Out:
#            City                Displinary     ExpDate FacLicNum   Id  \
# 0        Smyrna  1 Disciplinary Action(s)  03/31/2018  00000592  1.0
# 1       Seymour   No Disciplinary Actions              00000000  2.0
# 2  Mc Minnville   No Disciplinary Actions  11/30/2016  00000530  3.0
# 3  Murfreesboro   No Disciplinary Actions  04/30/2014  00000276  4.0
# 4    Cookeville   No Disciplinary Actions  02/28/2019  00000637  5.0
#
#                     MedDirector                              Name      OrgLic  \
# 0                  Hau La, M.D.             Absolute Medical Care  03/07/2016
# 1           GHOLAMREZA SHAREGHI    ACCELERATED MEDICAL OF SEYMOUR
# 2         FRANCISCO AVILA, M.D.                 ACCEPTANCE HEALTH  11/18/2014
# 3  LAWRENCE JOSEPH VALDEZ, M.D.   ACCESS SOLUTIONS WELLNESS, P.C.  04/03/2012
# 4            David McAfee, M.D.  Active Pain Management Solutions  02/02/2017
#
#           Phone State           Status                          Street    Zip
# 0  615-667-1299    TN  Lic Surrendered           713 B President Place  37167
# 1  865-216-8930    TN      Closed Appl            319 BLUE PEACOCK WAY  37865
# 2  931-507-6325    TN  Facility Closed      1012 SOUTH CHANCERY STREET  37110
# 3  615-962-9011    TN          Expired   805 S. CHURCH STREET SUITE 20  37130
# 4  931-526-7246    TN  Facility Closed  620 S Jefferson Ave, Suite 202  38501

# %%
# let's reorder the columns
col_names = ['Id', 'Name', 'Street', 'City', 'State', 'Zip', 'Phone', 'MedDirector', 'FacLicNum', 'Status', 'OrgLic',
            'ExpDate', 'Displinary']
out_df = out_df.reindex(columns=col_names)

# show the first five rows 
out_df.head()
# Out:
#     Id                              Name                          Street  \
# 0  1.0             Absolute Medical Care           713 B President Place
# 1  2.0    ACCELERATED MEDICAL OF SEYMOUR            319 BLUE PEACOCK WAY
# 2  3.0                 ACCEPTANCE HEALTH      1012 SOUTH CHANCERY STREET
# 3  4.0   ACCESS SOLUTIONS WELLNESS, P.C.   805 S. CHURCH STREET SUITE 20
# 4  5.0  Active Pain Management Solutions  620 S Jefferson Ave, Suite 202
#
#            City State    Zip         Phone                   MedDirector  \
# 0        Smyrna    TN  37167  615-667-1299                  Hau La, M.D.
# 1       Seymour    TN  37865  865-216-8930           GHOLAMREZA SHAREGHI
# 2  Mc Minnville    TN  37110  931-507-6325         FRANCISCO AVILA, M.D.
# 3  Murfreesboro    TN  37130  615-962-9011  LAWRENCE JOSEPH VALDEZ, M.D.
# 4    Cookeville    TN  38501  931-526-7246            David McAfee, M.D.
#
#   FacLicNum           Status      OrgLic     ExpDate                Displinary
# 0  00000592  Lic Surrendered  03/07/2016  03/31/2018  1 Disciplinary Action(s)
# 1  00000000      Closed Appl                           No Disciplinary Actions
# 2  00000530  Facility Closed  11/18/2014  11/30/2016   No Disciplinary Actions
# 3  00000276          Expired  04/03/2012  04/30/2014   No Disciplinary Actions
# 4  00000637  Facility Closed  02/02/2017  02/28/2019   No Disciplinary Actions

# %%
# save the dataframe to Excel
out_df.to_excel(out_excel_file, index=False)
